# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setMaster("local").setAppName("DegreesOfSeparation")
sc = SparkContext(conf = conf)

# %%
# Set the characters we wish to find the degree of separation between

# %%
startCharacterID = 5306 # Spiderman
targetCharacterID = 467 # BERSERKER II 859 #CAPTAIN AMERICA 14 # Adam

# %% [markdown]
# An accumulator allows many executors to increment a shared variable.
# counter = sc.accumulator(0) sets up a shared accumulator with initial value of 0. We can increment this value upon iteration and check for specific conditions once after iteration.

# %%
counter = sc.accumulator(0)

# %% [markdown]
# Breadth-First Search(BFS)

# %%
# BFS implementation

def convertToBFS(line):
    fields = line.split()
    heroID = int(fields[0])
    connections = []
    for connection in fields[1:]:
        connections.append(int(connection))
    color = 'WHITE'
    distance = 9999
    if(heroID == startCharacterID):
        color = 'GRAY'
    distance = 0
    return (heroID,(connections,distance,color))

# %%
def createStartingRdd():
    inputFile = sc.textFile("file:///C:/Users/dennis/Spark/Spark/resources/Marvel-Graph.txt")
    return inputFile.map(convertToBFS)

# %%
def bfsMap(node):
    characterID = node[0]
    data = node[1]
    connections = data[0]
    distance = data[1]
    color = data[2]

    results = []
    #If this node needs to be expanded...
    if (color == 'GRAY'):
        for connection in connections:
            newCharacterID = connection
            newDistance = distance + 1
            newColor = 'GRAY'
            if (targetCharacterID == connection):
                counter.add(1)

            newEntry = (newCharacterID, ([], newDistance, newColor))
            results.append(newEntry)

        #We've processed this node, so color it black
        color = 'BLACK'

    #Emit the input node so we don't lose it.
    results.append( (characterID, (connections, distance, color)) )
    return results

# %%
def bfsReduce(data1, data2):
    edges1 = data1[0]
    edges2 = data2[0]
    distance1 = data1[1]
    distance2 = data2[1]
    color1 = data1[2]
    color2 = data2[2]

    distance = 9999
    color = color1
    edges = []

    # See if one is the original node with its connections.
    # If so preserve them.
    if (len(edges1) > 0):
        edges.extend(edges1)
    if (len(edges2) > 0):
        edges.extend(edges2)

    # Preserve minimum distance
    if (distance1 < distance):
        distance = distance1

    if (distance2 < distance):
        distance = distance2

    # Preserve darkest color
    if (color1 == 'WHITE' and (color2 == 'GRAY' or color2 == 'BLACK')):
        color = color2

    if (color1 == 'GRAY' and color2 == 'BLACK'):
        color = color2

    if (color2 == 'WHITE' and (color1 == 'GRAY' or color1 == 'BLACK')):
        color = color1

    if (color2 == 'GRAY' and color1 == 'BLACK'):
        color = color1

    return (edges, distance, color)

# %%
#Main program here:
iterationRdd = createStartingRdd()

# %%
for iteration in range(0, 100):
    print("Running BFS iteration# " + str(iteration+1))

    # Create new vertices as needed to darken or reduce distances in the
    # reduce stage. If we encounter the node we're looking for as a GRAY
    # node, increment our accumulator to signal that we're done.
    mapped = iterationRdd.flatMap(bfsMap)

    # Note that mapped.count() action here forces the RDD to be evaluated, and
    # that's the only reason our accumulator is actually updated.
    print("Processing " + str(mapped.count()) + " values.")

    if (counter.value > 0):
        print("Hit the target character! From " + str(counter.value) \
            + " different direction(s).")
        break

    # Reducer combines data for each character ID, preserving the darkest
    # color and shortest path.
    iterationRdd = mapped.reduceByKey(bfsReduce)
# Out:
# Running BFS iteration# 1
# Processing 8330 values.
# Running BFS iteration# 2
# Processing 220615 values.
# Running BFS iteration# 3
# Processing 126747 values.
# Running BFS iteration# 4
# Processing 6777 values.
# Running BFS iteration# 5
# Processing 6486 values.
# Running BFS iteration# 6
# Processing 6486 values.
# Running BFS iteration# 7
# Processing 6486 values.
# Running BFS iteration# 8
# Processing 6486 values.
# Running BFS iteration# 9
# Processing 6486 values.
# Running BFS iteration# 10
# Processing 6486 values.
# Running BFS iteration# 11
# Processing 6486 values.
# Running BFS iteration# 12
# Processing 6486 values.
# Running BFS iteration# 13
# Processing 6486 values.
# Running BFS iteration# 14
# Processing 6486 values.
# Running BFS iteration# 15
# Processing 6486 values.
# Running BFS iteration# 16
# Processing 6486 values.
# Running BFS iteration# 17
# Processing 6486 values.
# Running BFS iteration# 18
# Processing 6486 values.
# Running BFS iteration# 19
# Processing 6486 values.
# Running BFS iteration# 20
# Processing 6486 values.
# Running BFS iteration# 21
# Processing 6486 values.
# Running BFS iteration# 22
# Processing 6486 values.
# Running BFS iteration# 23
# Processing 6486 values.
# Running BFS iteration# 24
# Processing 6486 values.
# Running BFS iteration# 25
# Processing 6486 values.
# Running BFS iteration# 26
# Processing 6486 values.
# Running BFS iteration# 27
# Processing 6486 values.
# Running BFS iteration# 28
# Processing 6486 values.
# Running BFS iteration# 29
# Processing 6486 values.
# Running BFS iteration# 30
# Processing 6486 values.
# Running BFS iteration# 31
# Processing 6486 values.
# Running BFS iteration# 32
# Processing 6486 values.
# Running BFS iteration# 33
# Processing 6486 values.
# Running BFS iteration# 34
# Processing 6486 values.
# Running BFS iteration# 35
# Processing 6486 values.
# Running BFS iteration# 36
# Processing 6486 values.
# Running BFS iteration# 37
# Processing 6486 values.
# Running BFS iteration# 38
# Processing 6486 values.
# Running BFS iteration# 39
# Processing 6486 values.
# Running BFS iteration# 40
# Processing 6486 values.
# Running BFS iteration# 41
# Processing 6486 values.
# Running BFS iteration# 42
# Processing 6486 values.
# Running BFS iteration# 43
# Processing 6486 values.
# Running BFS iteration# 44
# Processing 6486 values.
# Running BFS iteration# 45
# Processing 6486 values.
# Running BFS iteration# 46
# Processing 6486 values.
# Running BFS iteration# 47
# Processing 6486 values.
# Running BFS iteration# 48
# Processing 6486 values.
# Running BFS iteration# 49
# Processing 6486 values.
# Running BFS iteration# 50
# Processing 6486 values.
# Running BFS iteration# 51
# Processing 6486 values.
# Running BFS iteration# 52
# Processing 6486 values.
# Running BFS iteration# 53
# Processing 6486 values.
# Running BFS iteration# 54
# Processing 6486 values.
# Running BFS iteration# 55
# Processing 6486 values.
# Running BFS iteration# 56
# Processing 6486 values.
# Running BFS iteration# 57
# Processing 6486 values.
# Running BFS iteration# 58
# Processing 6486 values.
# Running BFS iteration# 59
# Processing 6486 values.
# Running BFS iteration# 60
# Processing 6486 values.
# Running BFS iteration# 61
# Processing 6486 values.
# Running BFS iteration# 62
# Processing 6486 values.
# Running BFS iteration# 63
# Processing 6486 values.
# Running BFS iteration# 64
# Processing 6486 values.
# Running BFS iteration# 65
# Processing 6486 values.
# Running BFS iteration# 66
# Processing 6486 values.
# Running BFS iteration# 67
# Processing 6486 values.
# Running BFS iteration# 68
# Processing 6486 values.
# Running BFS iteration# 69
# Processing 6486 values.
# Running BFS iteration# 70
# Processing 6486 values.
# Running BFS iteration# 71
# Processing 6486 values.
# Running BFS iteration# 72
# Processing 6486 values.
# Running BFS iteration# 73
# Processing 6486 values.
# Running BFS iteration# 74
# Processing 6486 values.
# Running BFS iteration# 75
# Processing 6486 values.
# Running BFS iteration# 76
# Processing 6486 values.
# Running BFS iteration# 77
# Processing 6486 values.
# Running BFS iteration# 78
# Processing 6486 values.
# Running BFS iteration# 79
# Processing 6486 values.
# Running BFS iteration# 80
# Processing 6486 values.
# Running BFS iteration# 81
# Processing 6486 values.
# Running BFS iteration# 82
# Processing 6486 values.
# Running BFS iteration# 83
# Processing 6486 values.
# Running BFS iteration# 84
# Processing 6486 values.
# Running BFS iteration# 85
# Processing 6486 values.
# Running BFS iteration# 86
# Processing 6486 values.
# Running BFS iteration# 87
# Processing 6486 values.
# Running BFS iteration# 88
# Processing 6486 values.
# Running BFS iteration# 89
# Processing 6486 values.
# Running BFS iteration# 90
# Processing 6486 values.
# Running BFS iteration# 91
# Processing 6486 values.
# Running BFS iteration# 92
# Processing 6486 values.
# Running BFS iteration# 93
# Processing 6486 values.
# Running BFS iteration# 94
# Processing 6486 values.
# Running BFS iteration# 95
# Processing 6486 values.
# Running BFS iteration# 96
# Processing 6486 values.
# Running BFS iteration# 97
# Processing 6486 values.
# Running BFS iteration# 98
# Processing 6486 values.
# Running BFS iteration# 99
# Processing 6486 values.
# Running BFS iteration# 100
# Processing 6486 values.
